# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataframe=pd.read_csv("winequality-red.csv")
dataframe.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
dataframe.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
x=dataframe.drop(columns='quality',axis=1)
y=dataframe['quality']

# %%
x.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model=DecisionTreeClassifier()
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
DecisionTreeClassifier()
# Out:
# DecisionTreeClassifier()

# %%
y_pred=model.predict(x_test)

# %%
y_pred
# Out:
# array([5, 6, 6, 5, 5, 5, 5, 6, 6, 6, 6, 5, 6, 5, 6, 5, 6, 5, 7, 6, 5, 6,
#        5, 7, 4, 5, 5, 6, 7, 7, 7, 5, 6, 6, 7, 5, 6, 6, 6, 7, 6, 6, 5, 5,
#        5, 5, 5, 6, 6, 5, 6, 6, 5, 5, 6, 5, 6, 6, 6, 6, 6, 6, 5, 5, 5, 5,
#        4, 7, 6, 6, 6, 5, 5, 5, 6, 6, 6, 6, 6, 6, 7, 6, 5, 5, 6, 4, 7, 6,
#        5, 7, 5, 5, 7, 5, 6, 6, 5, 7, 6, 5, 5, 5, 6, 4, 6, 7, 5, 5, 5, 6,
#        5, 5, 6, 5, 6, 6, 5, 5, 6, 5, 5, 6, 5, 6, 7, 5, 6, 5, 5, 4, 5, 6,
#        5, 5, 7, 6, 6, 6, 5, 4, 5, 6, 4, 5, 5, 6, 6, 5, 5, 6, 6, 6, 6, 7,
#        6, 6, 5, 5, 5, 5, 5, 6, 7, 5, 5, 5, 5, 5, 6, 5, 5, 5, 6, 5, 5, 5,
#        5, 5, 4, 6, 5, 5, 6, 6, 5, 6, 5, 5, 7, 5, 5, 5, 5, 5, 7, 6, 6, 6,
#        6, 5, 7, 5, 6, 4, 6, 5, 6, 5, 4, 6, 5, 6, 6, 4, 5, 6, 6, 6, 6, 5,
#        5, 5, 6, 6, 5, 8, 6, 6, 5, 5, 5, 7, 7, 4, 5, 5, 6, 5, 5, 5, 6, 5,
#        7, 6, 6, 6, 5, 6, 7, 7, 6, 7, 7, 7, 5, 7, 6, 6, 6, 6, 5, 7, 6, 8,
#        6, 6, 7, 6, 5, 5, 7, 7, 5, 5, 6, 5, 5, 6, 7, 7, 6, 6, 5, 4, 6, 7,
#        6, 5, 8, 4, 5, 5, 5, 5, 5, 7, 6, 6, 5, 5, 6, 5, 5, 5, 6, 6, 6, 5,
#        5, 5, 6, 6, 6, 5, 4, 6, 6, 5, 5, 6, 6, 7, 5, 6, 5, 6, 6, 6, 5, 5,
#        7, 6, 6, 6, 6, 6, 7, 5, 6, 6, 6, 6, 5, 6, 6, 6, 6, 6, 5, 6, 5, 6,
#        6, 6, 5, 6, 6, 6, 6, 6, 6, 7, 7, 5, 6, 6, 6, 6, 7, 7, 5, 6, 5, 5,
#        6, 5, 7, 7, 7, 6, 4, 7, 6, 6, 5, 6, 6, 7, 5, 7, 7, 6, 6, 6, 6, 6,
#        5, 6, 5, 5])

# %%
from sklearn import tree
plt.figure(figsize=(20,20))
tree.plot_tree(model,filled=True)
# Out:
# [Text(0.546030525128866, 0.9761904761904762, 'x[10] <= 10.55\ngini = 0.644\nsamples = 1199\nvalue = [7, 46, 512, 475, 145, 14]'),
#  Text(0.39095280283505157, 0.9285714285714286, 'x[6] <= 95.5\ngini = 0.551\nsamples = 744\nvalue = [5, 30, 433, 243, 31, 2]'),
#  Text(0.268503543814433, 0.8809523809523809, 'x[10] <= 9.85\ngini = 0.576\nsamples = 657\nvalue = [5, 29, 355, 235, 31, 2]'),
#  Text(0.1586952319587629, 0.8333333333333334, 'x[9] <= 0.575\ngini = 0.511\nsamples = 409\nvalue = [2, 19, 257, 124, 6, 1]'),
#  Text(0.06723582474226804, 0.7857142857142857, 'x[10] <= 9.05\ngini = 0.402\nsamples = 165\nvalue = [1, 13, 124, 27, 0, 0]'),
#  Text(0.053041237113402064, 0.7380952380952381, 'x[2] <= 0.085\ngini = 0.625\nsamples = 8\nvalue = [0, 2, 2, 4, 0, 0]'),
#  Text(0.04974226804123711, 0.6904761904761905, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0, 0]'),
#  Text(0.05634020618556701, 0.6904761904761905, 'x[3] <= 2.05\ngini = 0.444\nsamples = 6\nvalue = [0, 0, 2, 4, 0, 0]'),
#  Text(0.053041237113402064, 0.6428571428571429, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.059639175257731956, 0.6428571428571429, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.08143041237113402, 0.7380952380952381, 'x[1] <= 0.315\ngini = 0.37\nsamples = 157\nvalue = [1, 11, 122, 23, 0, 0]'),
#  Text(0.06953608247422681, 0.6904761904761905, 'x[4] <= 0.061\ngini = 0.56\nsamples = 5\nvalue = [0, 1, 1, 3, 0, 0]'),
#  Text(0.06623711340206186, 0.6428571428571429, 'x[6] <= 42.5\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]'),
#  Text(0.0629381443298969, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.06953608247422681, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.07283505154639175, 0.6428571428571429, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.09332474226804123, 0.6904761904761905, 'x[8] <= 3.54\ngini = 0.345\nsamples = 152\nvalue = [1, 10, 121, 20, 0, 0]'),
#  Text(0.09002577319587629, 0.6428571428571429, 'x[3] <= 4.4\ngini = 0.33\nsamples = 150\nvalue = [1, 10, 121, 18, 0, 0]'),
#  Text(0.0761340206185567, 0.5952380952380952, 'x[1] <= 0.757\ngini = 0.315\nsamples = 148\nvalue = [1, 9, 121, 17, 0, 0]'),
#  Text(0.05824742268041237, 0.5476190476190477, 'x[6] <= 88.5\ngini = 0.264\nsamples = 125\nvalue = [0, 3, 106, 16, 0, 0]'),
#  Text(0.0488659793814433, 0.5, 'x[6] <= 52.5\ngini = 0.238\nsamples = 119\nvalue = [0, 3, 103, 13, 0, 0]'),
#  Text(0.04556701030927835, 0.4523809523809524, 'x[6] <= 45.5\ngini = 0.332\nsamples = 80\nvalue = [0, 3, 64, 13, 0, 0]'),
#  Text(0.030103092783505155, 0.40476190476190477, 'x[10] <= 9.75\ngini = 0.269\nsamples = 70\nvalue = [0, 1, 59, 10, 0, 0]'),
#  Text(0.015670103092783504, 0.35714285714285715, 'x[6] <= 23.5\ngini = 0.222\nsamples = 64\nvalue = [0, 1, 56, 7, 0, 0]'),
#  Text(0.012371134020618556, 0.30952380952380953, 'gini = 0.0\nsamples = 23\nvalue = [0, 0, 23, 0, 0, 0]'),
#  Text(0.018969072164948454, 0.30952380952380953, 'x[6] <= 25.5\ngini = 0.322\nsamples = 41\nvalue = [0, 1, 33, 7, 0, 0]'),
#  Text(0.006597938144329897, 0.2619047619047619, 'x[4] <= 0.078\ngini = 0.625\nsamples = 4\nvalue = [0, 1, 1, 2, 0, 0]'),
#  Text(0.0032989690721649486, 0.21428571428571427, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.009896907216494845, 0.21428571428571427, 'x[8] <= 3.13\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]'),
#  Text(0.006597938144329897, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.013195876288659794, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.03134020618556701, 0.2619047619047619, 'x[10] <= 9.25\ngini = 0.234\nsamples = 37\nvalue = [0, 0, 32, 5, 0, 0]'),
#  Text(0.02309278350515464, 0.21428571428571427, 'x[6] <= 38.0\ngini = 0.5\nsamples = 4\nvalue = [0, 0, 2, 2, 0, 0]'),
#  Text(0.01979381443298969, 0.16666666666666666, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.02639175257731959, 0.16666666666666666, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.03958762886597938, 0.21428571428571427, 'x[6] <= 41.0\ngini = 0.165\nsamples = 33\nvalue = [0, 0, 30, 3, 0, 0]'),
#  Text(0.032989690721649485, 0.16666666666666666, 'x[6] <= 30.0\ngini = 0.071\nsamples = 27\nvalue = [0, 0, 26, 1, 0, 0]'),
#  Text(0.029690721649484535, 0.11904761904761904, 'x[0] <= 7.75\ngini = 0.198\nsamples = 9\nvalue = [0, 0, 8, 1, 0, 0]'),
#  Text(0.02639175257731959, 0.07142857142857142, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 8, 0, 0, 0]'),
#  Text(0.032989690721649485, 0.07142857142857142, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.03628865979381443, 0.11904761904761904, 'gini = 0.0\nsamples = 18\nvalue = [0, 0, 18, 0, 0, 0]'),
#  Text(0.04618556701030928, 0.16666666666666666, 'x[0] <= 8.0\ngini = 0.444\nsamples = 6\nvalue = [0, 0, 4, 2, 0, 0]'),
#  Text(0.04288659793814433, 0.11904761904761904, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.049484536082474224, 0.11904761904761904, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.0445360824742268, 0.35714285714285715, 'x[1] <= 0.593\ngini = 0.5\nsamples = 6\nvalue = [0, 0, 3, 3, 0, 0]'),
#  Text(0.041237113402061855, 0.30952380952380953, 'x[5] <= 3.5\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 1, 3, 0, 0]'),
#  Text(0.03793814432989691, 0.2619047619047619, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.0445360824742268, 0.2619047619047619, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.047835051546391755, 0.30952380952380953, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.06103092783505155, 0.40476190476190477, 'x[0] <= 8.4\ngini = 0.62\nsamples = 10\nvalue = [0, 2, 5, 3, 0, 0]'),
#  Text(0.0577319587628866, 0.35714285714285715, 'x[1] <= 0.42\ngini = 0.469\nsamples = 8\nvalue = [0, 0, 5, 3, 0, 0]'),
#  Text(0.05443298969072165, 0.30952380952380953, 'x[0] <= 5.85\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 1, 3, 0, 0]'),
#  Text(0.0511340206185567, 0.2619047619047619, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.0577319587628866, 0.2619047619047619, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.06103092783505155, 0.30952380952380953, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.0643298969072165, 0.35714285714285715, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0, 0]'),
#  Text(0.05216494845360825, 0.4523809523809524, 'gini = 0.0\nsamples = 39\nvalue = [0, 0, 39, 0, 0, 0]'),
#  Text(0.06762886597938145, 0.5, 'x[4] <= 0.083\ngini = 0.5\nsamples = 6\nvalue = [0, 0, 3, 3, 0, 0]'),
#  Text(0.0643298969072165, 0.4523809523809524, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.07092783505154639, 0.4523809523809524, 'x[3] <= 1.85\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 3, 1, 0, 0]'),
#  Text(0.06762886597938145, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.07422680412371134, 0.40476190476190477, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.09402061855670103, 0.5476190476190477, 'x[9] <= 0.485\ngini = 0.503\nsamples = 23\nvalue = [1, 6, 15, 1, 0, 0]'),
#  Text(0.08742268041237114, 0.5, 'x[7] <= 0.996\ngini = 0.531\nsamples = 8\nvalue = [0, 5, 2, 1, 0, 0]'),
#  Text(0.08412371134020619, 0.4523809523809524, 'x[3] <= 1.65\ngini = 0.625\nsamples = 4\nvalue = [0, 1, 2, 1, 0, 0]'),
#  Text(0.08082474226804123, 0.40476190476190477, 'x[7] <= 0.995\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 1, 0, 0]'),
#  Text(0.0775257731958763, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.08412371134020619, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.08742268041237114, 0.40476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.09072164948453608, 0.4523809523809524, 'gini = 0.0\nsamples = 4\nvalue = [0, 4, 0, 0, 0, 0]'),
#  Text(0.10061855670103093, 0.5, 'x[0] <= 6.9\ngini = 0.24\nsamples = 15\nvalue = [1, 1, 13, 0, 0, 0]'),
#  Text(0.09731958762886599, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]'),
#  Text(0.10391752577319588, 0.4523809523809524, 'x[0] <= 8.9\ngini = 0.133\nsamples = 14\nvalue = [0, 1, 13, 0, 0, 0]'),
#  Text(0.10061855670103093, 0.40476190476190477, 'gini = 0.0\nsamples = 12\nvalue = [0, 0, 12, 0, 0, 0]'),
#  Text(0.10721649484536082, 0.40476190476190477, 'x[8] <= 3.385\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]'),
#  Text(0.10391752577319588, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.11051546391752577, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.10391752577319588, 0.5952380952380952, 'x[8] <= 3.225\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 1, 0, 0]'),
#  Text(0.10061855670103093, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.10721649484536082, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.09662371134020618, 0.6428571428571429, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.2501546391752577, 0.7857142857142857, 'x[0] <= 10.05\ngini = 0.544\nsamples = 244\nvalue = [1, 6, 133, 97, 6, 1]'),
#  Text(0.2034020618556701, 0.7380952380952381, 'x[0] <= 8.75\ngini = 0.508\nsamples = 204\nvalue = [0, 6, 124, 71, 3, 0]'),
#  Text(0.14701030927835051, 0.6904761904761905, 'x[0] <= 6.85\ngini = 0.525\nsamples = 170\nvalue = [0, 5, 96, 67, 2, 0]'),
#  Text(0.12371134020618557, 0.6428571428571429, 'x[1] <= 0.435\ngini = 0.219\nsamples = 24\nvalue = [0, 0, 21, 3, 0, 0]'),
#  Text(0.11711340206185566, 0.5952380952380952, 'x[10] <= 9.45\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(0.11381443298969073, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.12041237113402062, 0.5476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.13030927835051545, 0.5952380952380952, 'x[7] <= 0.996\ngini = 0.091\nsamples = 21\nvalue = [0, 0, 20, 1, 0, 0]'),
#  Text(0.12701030927835052, 0.5476190476190477, 'x[10] <= 9.45\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 1, 0, 0]'),
#  Text(0.12371134020618557, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.13030927835051545, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.1336082474226804, 0.5476190476190477, 'gini = 0.0\nsamples = 18\nvalue = [0, 0, 18, 0, 0, 0]'),
#  Text(0.17030927835051546, 0.6428571428571429, 'x[8] <= 3.205\ngini = 0.543\nsamples = 146\nvalue = [0, 5, 75, 64, 2, 0]'),
#  Text(0.14680412371134022, 0.5952380952380952, 'x[6] <= 34.5\ngini = 0.347\nsamples = 29\nvalue = [0, 2, 23, 4, 0, 0]'),
#  Text(0.1402061855670103, 0.5476190476190477, 'x[3] <= 1.5\ngini = 0.375\nsamples = 4\nvalue = [0, 1, 0, 3, 0, 0]'),
#  Text(0.13690721649484536, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.14350515463917526, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.1534020618556701, 0.5476190476190477, 'x[5] <= 6.0\ngini = 0.15\nsamples = 25\nvalue = [0, 1, 23, 1, 0, 0]'),
#  Text(0.15010309278350514, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.15670103092783505, 0.5, 'x[4] <= 0.095\ngini = 0.08\nsamples = 24\nvalue = [0, 1, 23, 0, 0, 0]'),
#  Text(0.1534020618556701, 0.4523809523809524, 'x[6] <= 69.0\ngini = 0.375\nsamples = 4\nvalue = [0, 1, 3, 0, 0, 0]'),
#  Text(0.15010309278350514, 0.40476190476190477, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.15670103092783505, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.16, 0.4523809523809524, 'gini = 0.0\nsamples = 20\nvalue = [0, 0, 20, 0, 0, 0]'),
#  Text(0.19381443298969073, 0.5952380952380952, 'x[7] <= 0.996\ngini = 0.539\nsamples = 117\nvalue = [0, 3, 52, 60, 2, 0]'),
#  Text(0.17649484536082474, 0.5476190476190477, 'x[7] <= 0.996\ngini = 0.445\nsamples = 20\nvalue = [0, 1, 14, 5, 0, 0]'),
#  Text(0.16989690721649484, 0.5, 'x[2] <= 0.08\ngini = 0.611\nsamples = 6\nvalue = [0, 1, 2, 3, 0, 0]'),
#  Text(0.1665979381443299, 0.4523809523809524, 'x[3] <= 1.75\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2, 0, 0, 0]'),
#  Text(0.16329896907216496, 0.40476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.16989690721649484, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.1731958762886598, 0.4523809523809524, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.18309278350515465, 0.5, 'x[4] <= 0.151\ngini = 0.245\nsamples = 14\nvalue = [0, 0, 12, 2, 0, 0]'),
#  Text(0.1797938144329897, 0.4523809523809524, 'x[6] <= 77.0\ngini = 0.142\nsamples = 13\nvalue = [0, 0, 12, 1, 0, 0]'),
#  Text(0.17649484536082474, 0.40476190476190477, 'gini = 0.0\nsamples = 11\nvalue = [0, 0, 11, 0, 0, 0]'),
#  Text(0.18309278350515465, 0.40476190476190477, 'x[5] <= 13.0\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.1797938144329897, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.18639175257731957, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.18639175257731957, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.2111340206185567, 0.5476190476190477, 'x[6] <= 28.5\ngini = 0.524\nsamples = 97\nvalue = [0, 2, 38, 55, 2, 0]'),
#  Text(0.20288659793814434, 0.5, 'x[8] <= 3.305\ngini = 0.346\nsamples = 27\nvalue = [0, 0, 6, 21, 0, 0]'),
#  Text(0.1995876288659794, 0.4523809523809524, 'x[1] <= 0.583\ngini = 0.496\nsamples = 11\nvalue = [0, 0, 6, 5, 0, 0]'),
#  Text(0.19628865979381444, 0.40476190476190477, 'x[9] <= 0.83\ngini = 0.408\nsamples = 7\nvalue = [0, 0, 2, 5, 0, 0]'),
#  Text(0.19298969072164948, 0.35714285714285715, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(0.1995876288659794, 0.35714285714285715, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.20288659793814434, 0.40476190476190477, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.20618556701030927, 0.4523809523809524, 'gini = 0.0\nsamples = 16\nvalue = [0, 0, 0, 16, 0, 0]'),
#  Text(0.21938144329896908, 0.5, 'x[3] <= 1.65\ngini = 0.553\nsamples = 70\nvalue = [0, 2, 32, 34, 2, 0]'),
#  Text(0.21608247422680413, 0.4523809523809524, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]'),
#  Text(0.22268041237113403, 0.4523809523809524, 'x[9] <= 0.595\ngini = 0.552\nsamples = 65\nvalue = [0, 2, 27, 34, 2, 0]'),
#  Text(0.20948453608247422, 0.40476190476190477, 'x[3] <= 2.4\ngini = 0.231\nsamples = 15\nvalue = [0, 0, 2, 13, 0, 0]'),
#  Text(0.20618556701030927, 0.35714285714285715, 'x[2] <= 0.315\ngini = 0.133\nsamples = 14\nvalue = [0, 0, 1, 13, 0, 0]'),
#  Text(0.20288659793814434, 0.30952380952380953, 'gini = 0.0\nsamples = 12\nvalue = [0, 0, 0, 12, 0, 0]'),
#  Text(0.20948453608247422, 0.30952380952380953, 'x[9] <= 0.585\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.20618556701030927, 0.2619047619047619, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.21278350515463917, 0.2619047619047619, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.21278350515463917, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.23587628865979382, 0.40476190476190477, 'x[3] <= 2.35\ngini = 0.57\nsamples = 50\nvalue = [0, 2, 25, 21, 2, 0]'),
#  Text(0.2292783505154639, 0.35714285714285715, 'x[1] <= 0.575\ngini = 0.478\nsamples = 33\nvalue = [0, 0, 22, 9, 2, 0]'),
#  Text(0.22597938144329896, 0.30952380952380953, 'x[4] <= 0.077\ngini = 0.58\nsamples = 21\nvalue = [0, 0, 10, 9, 2, 0]'),
#  Text(0.21938144329896908, 0.2619047619047619, 'x[8] <= 3.31\ngini = 0.245\nsamples = 7\nvalue = [0, 0, 6, 0, 1, 0]'),
#  Text(0.21608247422680413, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.22268041237113403, 0.21428571428571427, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 6, 0, 0, 0]'),
#  Text(0.23257731958762887, 0.2619047619047619, 'x[8] <= 3.47\ngini = 0.5\nsamples = 14\nvalue = [0, 0, 4, 9, 1, 0]'),
#  Text(0.2292783505154639, 0.21428571428571427, 'x[6] <= 36.5\ngini = 0.314\nsamples = 11\nvalue = [0, 0, 1, 9, 1, 0]'),
#  Text(0.22597938144329896, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.23257731958762887, 0.16666666666666666, 'x[3] <= 2.05\ngini = 0.18\nsamples = 10\nvalue = [0, 0, 1, 9, 0, 0]'),
#  Text(0.2292783505154639, 0.11904761904761904, 'gini = 0.0\nsamples = 9\nvalue = [0, 0, 0, 9, 0, 0]'),
#  Text(0.23587628865979382, 0.11904761904761904, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.23587628865979382, 0.21428571428571427, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.23257731958762887, 0.30952380952380953, 'gini = 0.0\nsamples = 12\nvalue = [0, 0, 12, 0, 0, 0]'),
#  Text(0.2424742268041237, 0.35714285714285715, 'x[5] <= 20.0\ngini = 0.457\nsamples = 17\nvalue = [0, 2, 3, 12, 0, 0]'),
#  Text(0.23917525773195877, 0.30952380952380953, 'gini = 0.0\nsamples = 11\nvalue = [0, 0, 0, 11, 0, 0]'),
#  Text(0.24577319587628865, 0.30952380952380953, 'x[6] <= 50.5\ngini = 0.611\nsamples = 6\nvalue = [0, 2, 3, 1, 0, 0]'),
#  Text(0.2424742268041237, 0.2619047619047619, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.2490721649484536, 0.2619047619047619, 'x[9] <= 0.655\ngini = 0.48\nsamples = 5\nvalue = [0, 2, 3, 0, 0, 0]'),
#  Text(0.24577319587628865, 0.21428571428571427, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.25237113402061856, 0.21428571428571427, 'x[6] <= 89.0\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1, 0, 0, 0]'),
#  Text(0.2490721649484536, 0.16666666666666666, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0, 0]'),
#  Text(0.2556701030927835, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.2597938144329897, 0.6904761904761905, 'x[2] <= 0.635\ngini = 0.306\nsamples = 34\nvalue = [0, 1, 28, 4, 1, 0]'),
#  Text(0.25072164948453607, 0.6428571428571429, 'x[3] <= 7.2\ngini = 0.225\nsamples = 32\nvalue = [0, 0, 28, 3, 1, 0]'),
#  Text(0.2424742268041237, 0.5952380952380952, 'x[4] <= 0.159\ngini = 0.135\nsamples = 28\nvalue = [0, 0, 26, 1, 1, 0]'),
#  Text(0.23587628865979382, 0.5476190476190477, 'x[9] <= 0.61\ngini = 0.074\nsamples = 26\nvalue = [0, 0, 25, 0, 1, 0]'),
#  Text(0.23257731958762887, 0.5, 'x[9] <= 0.595\ngini = 0.245\nsamples = 7\nvalue = [0, 0, 6, 0, 1, 0]'),
#  Text(0.2292783505154639, 0.4523809523809524, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 6, 0, 0, 0]'),
#  Text(0.23587628865979382, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.23917525773195877, 0.5, 'gini = 0.0\nsamples = 19\nvalue = [0, 0, 19, 0, 0, 0]'),
#  Text(0.2490721649484536, 0.5476190476190477, 'x[9] <= 0.85\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.24577319587628865, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.25237113402061856, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.25896907216494847, 0.5952380952380952, 'x[10] <= 9.0\ngini = 0.5\nsamples = 4\nvalue = [0, 0, 2, 2, 0, 0]'),
#  Text(0.2556701030927835, 0.5476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.2622680412371134, 0.5476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.2688659793814433, 0.6428571428571429, 'x[5] <= 25.0\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 1, 0, 0]'),
#  Text(0.2655670103092784, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.2721649484536082, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.29690721649484536, 0.7380952380952381, 'x[0] <= 14.65\ngini = 0.52\nsamples = 40\nvalue = [1, 0, 9, 26, 3, 1]'),
#  Text(0.29360824742268044, 0.6904761904761905, 'x[5] <= 5.5\ngini = 0.474\nsamples = 38\nvalue = [1, 0, 9, 26, 1, 1]'),
#  Text(0.2820618556701031, 0.6428571428571429, 'x[3] <= 2.45\ngini = 0.56\nsamples = 5\nvalue = [1, 0, 3, 1, 0, 0]'),
#  Text(0.27876288659793813, 0.5952380952380952, 'x[1] <= 0.52\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 0, 1, 0, 0]'),
#  Text(0.2754639175257732, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.2820618556701031, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]'),
#  Text(0.28536082474226804, 0.5952380952380952, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.30515463917525776, 0.6428571428571429, 'x[9] <= 1.27\ngini = 0.391\nsamples = 33\nvalue = [0, 0, 6, 25, 1, 1]'),
#  Text(0.3018556701030928, 0.5952380952380952, 'x[2] <= 0.575\ngini = 0.354\nsamples = 32\nvalue = [0, 0, 6, 25, 0, 1]'),
#  Text(0.28865979381443296, 0.5476190476190477, 'x[9] <= 0.645\ngini = 0.26\nsamples = 26\nvalue = [0, 0, 4, 22, 0, 0]'),
#  Text(0.27876288659793813, 0.5, 'x[5] <= 6.5\ngini = 0.469\nsamples = 8\nvalue = [0, 0, 3, 5, 0, 0]'),
#  Text(0.2754639175257732, 0.4523809523809524, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.2820618556701031, 0.4523809523809524, 'x[1] <= 0.31\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 3, 1, 0, 0]'),
#  Text(0.27876288659793813, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.28536082474226804, 0.40476190476190477, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.29855670103092785, 0.5, 'x[6] <= 16.5\ngini = 0.105\nsamples = 18\nvalue = [0, 0, 1, 17, 0, 0]'),
#  Text(0.29525773195876287, 0.4523809523809524, 'x[6] <= 15.5\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 1, 4, 0, 0]'),
#  Text(0.29195876288659794, 0.40476190476190477, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.29855670103092785, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.3018556701030928, 0.4523809523809524, 'gini = 0.0\nsamples = 13\nvalue = [0, 0, 0, 13, 0, 0]'),
#  Text(0.3150515463917526, 0.5476190476190477, 'x[7] <= 1.0\ngini = 0.611\nsamples = 6\nvalue = [0, 0, 2, 3, 0, 1]'),
#  Text(0.3117525773195876, 0.5, 'x[2] <= 0.665\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 0, 0, 1]'),
#  Text(0.3084536082474227, 0.4523809523809524, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.3150515463917526, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.3183505154639175, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.3084536082474227, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.3002061855670103, 0.6904761904761905, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.3783118556701031, 0.8333333333333334, 'x[9] <= 0.485\ngini = 0.632\nsamples = 248\nvalue = [3, 10, 98, 111, 25, 1]'),
#  Text(0.3249484536082474, 0.7857142857142857, 'x[7] <= 0.994\ngini = 0.4\nsamples = 25\nvalue = [0, 3, 19, 2, 1, 0]'),
#  Text(0.3216494845360825, 0.7380952380952381, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0, 0]'),
#  Text(0.32824742268041235, 0.7380952380952381, 'x[3] <= 1.3\ngini = 0.306\nsamples = 23\nvalue = [0, 1, 19, 2, 1, 0]'),
#  Text(0.3249484536082474, 0.6904761904761905, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.33154639175257733, 0.6904761904761905, 'x[2] <= 0.265\ngini = 0.244\nsamples = 22\nvalue = [0, 1, 19, 2, 0, 0]'),
#  Text(0.32824742268041235, 0.6428571428571429, 'gini = 0.0\nsamples = 16\nvalue = [0, 0, 16, 0, 0, 0]'),
#  Text(0.33484536082474226, 0.6428571428571429, 'x[1] <= 0.793\ngini = 0.611\nsamples = 6\nvalue = [0, 1, 3, 2, 0, 0]'),
#  Text(0.33154639175257733, 0.5952380952380952, 'x[1] <= 0.657\ngini = 0.48\nsamples = 5\nvalue = [0, 0, 3, 2, 0, 0]'),
#  Text(0.32824742268041235, 0.5476190476190477, 'x[7] <= 0.997\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(0.3249484536082474, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.33154639175257733, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.33484536082474226, 0.5476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.33814432989690724, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.43167525773195875, 0.7857142857142857, 'x[8] <= 3.425\ngini = 0.623\nsamples = 223\nvalue = [3, 7, 79, 109, 24, 1]'),
#  Text(0.40685567010309276, 0.7380952380952381, 'x[6] <= 79.0\ngini = 0.603\nsamples = 184\nvalue = [2, 5, 54, 100, 22, 1]'),
#  Text(0.3850515463917526, 0.6904761904761905, 'x[2] <= 0.315\ngini = 0.594\nsamples = 175\nvalue = [2, 5, 46, 99, 22, 1]'),
#  Text(0.351340206185567, 0.6428571428571429, 'x[6] <= 13.5\ngini = 0.472\nsamples = 103\nvalue = [1, 1, 26, 70, 5, 0]'),
#  Text(0.3447422680412371, 0.5952380952380952, 'x[7] <= 0.998\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 3, 0, 1, 0]'),
#  Text(0.34144329896907216, 0.5476190476190477, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.34804123711340207, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.3579381443298969, 0.5952380952380952, 'x[9] <= 0.965\ngini = 0.444\nsamples = 99\nvalue = [1, 1, 23, 70, 4, 0]'),
#  Text(0.354639175257732, 0.5476190476190477, 'x[6] <= 61.5\ngini = 0.43\nsamples = 97\nvalue = [1, 1, 21, 70, 4, 0]'),
#  Text(0.34350515463917525, 0.5, 'x[9] <= 0.705\ngini = 0.483\nsamples = 79\nvalue = [1, 1, 20, 53, 4, 0]'),
#  Text(0.3402061855670103, 0.4523809523809524, 'x[1] <= 0.66\ngini = 0.524\nsamples = 69\nvalue = [1, 1, 20, 43, 4, 0]'),
#  Text(0.32783505154639175, 0.40476190476190477, 'x[9] <= 0.69\ngini = 0.481\nsamples = 53\nvalue = [0, 1, 12, 36, 4, 0]'),
#  Text(0.32453608247422683, 0.35714285714285715, 'x[6] <= 31.5\ngini = 0.444\nsamples = 51\nvalue = [0, 1, 12, 36, 2, 0]'),
#  Text(0.3096907216494845, 0.30952380952380953, 'x[2] <= 0.015\ngini = 0.314\nsamples = 28\nvalue = [0, 1, 2, 23, 2, 0]'),
#  Text(0.3030927835051546, 0.2619047619047619, 'x[2] <= 0.005\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 1, 2, 0]'),
#  Text(0.2997938144329897, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.3063917525773196, 0.21428571428571427, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.31628865979381443, 0.2619047619047619, 'x[6] <= 14.5\ngini = 0.218\nsamples = 25\nvalue = [0, 1, 2, 22, 0, 0]'),
#  Text(0.3129896907216495, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.31958762886597936, 0.21428571428571427, 'x[7] <= 0.996\ngini = 0.153\nsamples = 24\nvalue = [0, 0, 2, 22, 0, 0]'),
#  Text(0.31628865979381443, 0.16666666666666666, 'x[10] <= 10.3\ngini = 0.375\nsamples = 8\nvalue = [0, 0, 2, 6, 0, 0]'),
#  Text(0.3129896907216495, 0.11904761904761904, 'x[10] <= 9.95\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 1, 0, 0]'),
#  Text(0.3096907216494845, 0.07142857142857142, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.31628865979381443, 0.07142857142857142, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.31958762886597936, 0.11904761904761904, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(0.32288659793814434, 0.16666666666666666, 'gini = 0.0\nsamples = 16\nvalue = [0, 0, 0, 16, 0, 0]'),
#  Text(0.3393814432989691, 0.30952380952380953, 'x[8] <= 3.375\ngini = 0.491\nsamples = 23\nvalue = [0, 0, 10, 13, 0, 0]'),
#  Text(0.33608247422680415, 0.2619047619047619, 'x[7] <= 0.998\ngini = 0.469\nsamples = 16\nvalue = [0, 0, 10, 6, 0, 0]'),
#  Text(0.33278350515463917, 0.21428571428571427, 'x[9] <= 0.63\ngini = 0.355\nsamples = 13\nvalue = [0, 0, 10, 3, 0, 0]'),
#  Text(0.32948453608247424, 0.16666666666666666, 'x[1] <= 0.39\ngini = 0.278\nsamples = 12\nvalue = [0, 0, 10, 2, 0, 0]'),
#  Text(0.32618556701030926, 0.11904761904761904, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.33278350515463917, 0.11904761904761904, 'x[4] <= 0.085\ngini = 0.165\nsamples = 11\nvalue = [0, 0, 10, 1, 0, 0]'),
#  Text(0.32948453608247424, 0.07142857142857142, 'gini = 0.0\nsamples = 9\nvalue = [0, 0, 9, 0, 0, 0]'),
#  Text(0.33608247422680415, 0.07142857142857142, 'x[9] <= 0.59\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.33278350515463917, 0.023809523809523808, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.3393814432989691, 0.023809523809523808, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.33608247422680415, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.3393814432989691, 0.21428571428571427, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.342680412371134, 0.2619047619047619, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 7, 0, 0]'),
#  Text(0.3311340206185567, 0.35714285714285715, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.3525773195876289, 0.40476190476190477, 'x[2] <= 0.125\ngini = 0.555\nsamples = 16\nvalue = [1, 0, 8, 7, 0, 0]'),
#  Text(0.3492783505154639, 0.35714285714285715, 'x[3] <= 3.2\ngini = 0.37\nsamples = 9\nvalue = [1, 0, 1, 7, 0, 0]'),
#  Text(0.345979381443299, 0.30952380952380953, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 7, 0, 0]'),
#  Text(0.3525773195876289, 0.30952380952380953, 'x[7] <= 0.998\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 1, 0, 0, 0]'),
#  Text(0.3492783505154639, 0.2619047619047619, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.3558762886597938, 0.2619047619047619, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]'),
#  Text(0.3558762886597938, 0.35714285714285715, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 7, 0, 0, 0]'),
#  Text(0.34680412371134023, 0.4523809523809524, 'gini = 0.0\nsamples = 10\nvalue = [0, 0, 0, 10, 0, 0]'),
#  Text(0.36577319587628865, 0.5, 'x[3] <= 2.05\ngini = 0.105\nsamples = 18\nvalue = [0, 0, 1, 17, 0, 0]'),
#  Text(0.3624742268041237, 0.4523809523809524, 'x[0] <= 8.5\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(0.35917525773195874, 0.40476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.36577319587628865, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.36907216494845363, 0.4523809523809524, 'gini = 0.0\nsamples = 15\nvalue = [0, 0, 0, 15, 0, 0]'),
#  Text(0.3612371134020619, 0.5476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.41876288659793814, 0.6428571428571429, 'x[9] <= 0.635\ngini = 0.701\nsamples = 72\nvalue = [1, 4, 20, 29, 17, 1]'),
#  Text(0.3938144329896907, 0.5952380952380952, 'x[5] <= 13.0\ngini = 0.583\nsamples = 22\nvalue = [0, 3, 12, 7, 0, 0]'),
#  Text(0.38556701030927837, 0.5476190476190477, 'x[0] <= 7.35\ngini = 0.477\nsamples = 16\nvalue = [0, 2, 11, 3, 0, 0]'),
#  Text(0.37896907216494846, 0.5, 'x[2] <= 0.505\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 1, 0, 0]'),
#  Text(0.3756701030927835, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.3822680412371134, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.3921649484536082, 0.5, 'x[1] <= 0.615\ngini = 0.357\nsamples = 14\nvalue = [0, 1, 11, 2, 0, 0]'),
#  Text(0.3888659793814433, 0.4523809523809524, 'x[9] <= 0.62\ngini = 0.26\nsamples = 13\nvalue = [0, 0, 11, 2, 0, 0]'),
#  Text(0.38556701030927837, 0.40476190476190477, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 8, 0, 0, 0]'),
#  Text(0.3921649484536082, 0.40476190476190477, 'x[7] <= 0.997\ngini = 0.48\nsamples = 5\nvalue = [0, 0, 3, 2, 0, 0]'),
#  Text(0.3888659793814433, 0.35714285714285715, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.3954639175257732, 0.35714285714285715, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.3954639175257732, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.4020618556701031, 0.5476190476190477, 'x[1] <= 0.557\ngini = 0.5\nsamples = 6\nvalue = [0, 1, 1, 4, 0, 0]'),
#  Text(0.3987628865979381, 0.5, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.40536082474226803, 0.5, 'x[0] <= 9.5\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]'),
#  Text(0.4020618556701031, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.408659793814433, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.4437113402061856, 0.5952380952380952, 'x[3] <= 5.35\ngini = 0.664\nsamples = 50\nvalue = [1, 1, 8, 22, 17, 1]'),
#  Text(0.4404123711340206, 0.5476190476190477, 'x[4] <= 0.122\ngini = 0.66\nsamples = 46\nvalue = [1, 1, 8, 22, 13, 1]'),
#  Text(0.4218556701030928, 0.5, 'x[8] <= 3.03\ngini = 0.591\nsamples = 40\nvalue = [0, 0, 5, 22, 12, 1]'),
#  Text(0.41525773195876287, 0.4523809523809524, 'x[2] <= 0.61\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 1, 0, 3, 0]'),
#  Text(0.41195876288659794, 0.40476190476190477, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]'),
#  Text(0.41855670103092785, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.4284536082474227, 0.4523809523809524, 'x[2] <= 0.325\ngini = 0.551\nsamples = 36\nvalue = [0, 0, 4, 22, 9, 1]'),
#  Text(0.42515463917525775, 0.40476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.4317525773195876, 0.40476190476190477, 'x[10] <= 10.45\ngini = 0.524\nsamples = 34\nvalue = [0, 0, 4, 22, 7, 1]'),
#  Text(0.4144329896907217, 0.35714285714285715, 'x[7] <= 0.997\ngini = 0.445\nsamples = 29\nvalue = [0, 0, 3, 21, 4, 1]'),
#  Text(0.39958762886597937, 0.30952380952380953, 'x[7] <= 0.996\ngini = 0.722\nsamples = 6\nvalue = [0, 0, 1, 2, 2, 1]'),
#  Text(0.39628865979381445, 0.2619047619047619, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.40288659793814435, 0.2619047619047619, 'x[8] <= 3.225\ngini = 0.625\nsamples = 4\nvalue = [0, 0, 1, 0, 2, 1]'),
#  Text(0.39958762886597937, 0.21428571428571427, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.4061855670103093, 0.21428571428571427, 'x[5] <= 6.0\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 0, 0, 1]'),
#  Text(0.40288659793814435, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.4094845360824742, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.4292783505154639, 0.30952380952380953, 'x[1] <= 0.422\ngini = 0.302\nsamples = 23\nvalue = [0, 0, 2, 19, 2, 0]'),
#  Text(0.422680412371134, 0.2619047619047619, 'x[4] <= 0.072\ngini = 0.198\nsamples = 18\nvalue = [0, 0, 2, 16, 0, 0]'),
#  Text(0.4193814432989691, 0.21428571428571427, 'x[7] <= 0.998\ngini = 0.444\nsamples = 6\nvalue = [0, 0, 2, 4, 0, 0]'),
#  Text(0.4160824742268041, 0.16666666666666666, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.422680412371134, 0.16666666666666666, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.42597938144329894, 0.21428571428571427, 'gini = 0.0\nsamples = 12\nvalue = [0, 0, 0, 12, 0, 0]'),
#  Text(0.43587628865979383, 0.2619047619047619, 'x[1] <= 0.435\ngini = 0.48\nsamples = 5\nvalue = [0, 0, 0, 3, 2, 0]'),
#  Text(0.43257731958762885, 0.21428571428571427, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.43917525773195876, 0.21428571428571427, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.4490721649484536, 0.35714285714285715, 'x[9] <= 0.735\ngini = 0.56\nsamples = 5\nvalue = [0, 0, 1, 1, 3, 0]'),
#  Text(0.44577319587628866, 0.30952380952380953, 'x[8] <= 3.15\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.44247422680412374, 0.2619047619047619, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.4490721649484536, 0.2619047619047619, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.45237113402061857, 0.30952380952380953, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]'),
#  Text(0.4589690721649485, 0.5, 'x[10] <= 9.95\ngini = 0.667\nsamples = 6\nvalue = [1, 1, 3, 0, 1, 0]'),
#  Text(0.4556701030927835, 0.4523809523809524, 'x[4] <= 0.146\ngini = 0.667\nsamples = 3\nvalue = [1, 1, 0, 0, 1, 0]'),
#  Text(0.45237113402061857, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]'),
#  Text(0.4589690721649485, 0.40476190476190477, 'x[5] <= 20.5\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 0, 1, 0]'),
#  Text(0.4556701030927835, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.4622680412371134, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.4622680412371134, 0.4523809523809524, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.4470103092783505, 0.5476190476190477, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 0, 4, 0]'),
#  Text(0.428659793814433, 0.6904761904761905, 'x[5] <= 24.0\ngini = 0.198\nsamples = 9\nvalue = [0, 0, 8, 1, 0, 0]'),
#  Text(0.42536082474226805, 0.6428571428571429, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 8, 0, 0, 0]'),
#  Text(0.43195876288659796, 0.6428571428571429, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.45649484536082474, 0.7380952380952381, 'x[1] <= 0.31\ngini = 0.53\nsamples = 39\nvalue = [1, 2, 25, 9, 2, 0]'),
#  Text(0.44577319587628866, 0.6904761904761905, 'x[6] <= 64.0\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 0, 3, 1, 0]'),
#  Text(0.44247422680412374, 0.6428571428571429, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.4490721649484536, 0.6428571428571429, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.4672164948453608, 0.6904761904761905, 'x[5] <= 6.5\ngini = 0.456\nsamples = 35\nvalue = [1, 2, 25, 6, 1, 0]'),
#  Text(0.4556701030927835, 0.6428571428571429, 'x[2] <= 0.01\ngini = 0.667\nsamples = 3\nvalue = [1, 1, 0, 1, 0, 0]'),
#  Text(0.45237113402061857, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.4589690721649485, 0.5952380952380952, 'x[0] <= 6.15\ngini = 0.5\nsamples = 2\nvalue = [1, 1, 0, 0, 0, 0]'),
#  Text(0.4556701030927835, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.4622680412371134, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]'),
#  Text(0.47876288659793814, 0.6428571428571429, 'x[6] <= 49.5\ngini = 0.363\nsamples = 32\nvalue = [0, 1, 25, 5, 1, 0]'),
#  Text(0.4754639175257732, 0.5952380952380952, 'x[4] <= 0.075\ngini = 0.51\nsamples = 20\nvalue = [0, 1, 13, 5, 1, 0]'),
#  Text(0.4688659793814433, 0.5476190476190477, 'x[1] <= 0.465\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 0, 2, 0, 0]'),
#  Text(0.46556701030927833, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.47216494845360824, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.48206185567010307, 0.5476190476190477, 'x[0] <= 6.75\ngini = 0.381\nsamples = 17\nvalue = [0, 0, 13, 3, 1, 0]'),
#  Text(0.47876288659793814, 0.5, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 8, 0, 0, 0]'),
#  Text(0.48536082474226805, 0.5, 'x[6] <= 42.5\ngini = 0.568\nsamples = 9\nvalue = [0, 0, 5, 3, 1, 0]'),
#  Text(0.48206185567010307, 0.4523809523809524, 'x[10] <= 10.05\ngini = 0.449\nsamples = 7\nvalue = [0, 0, 5, 1, 1, 0]'),
#  Text(0.47876288659793814, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.48536082474226805, 0.40476190476190477, 'x[1] <= 0.575\ngini = 0.278\nsamples = 6\nvalue = [0, 0, 5, 0, 1, 0]'),
#  Text(0.48206185567010307, 0.35714285714285715, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.488659793814433, 0.35714285714285715, 'x[9] <= 0.645\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 0, 1, 0]'),
#  Text(0.48536082474226805, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.49195876288659796, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.488659793814433, 0.4523809523809524, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.48206185567010307, 0.5952380952380952, 'gini = 0.0\nsamples = 12\nvalue = [0, 0, 12, 0, 0, 0]'),
#  Text(0.51340206185567, 0.8809523809523809, 'x[6] <= 156.5\ngini = 0.188\nsamples = 87\nvalue = [0, 1, 78, 8, 0, 0]'),
#  Text(0.5101030927835052, 0.8333333333333334, 'x[5] <= 21.5\ngini = 0.171\nsamples = 86\nvalue = [0, 1, 78, 7, 0, 0]'),
#  Text(0.5018556701030927, 0.7857142857142857, 'x[9] <= 1.175\ngini = 0.32\nsamples = 30\nvalue = [0, 0, 24, 6, 0, 0]'),
#  Text(0.4952577319587629, 0.7380952380952381, 'x[1] <= 0.738\ngini = 0.252\nsamples = 27\nvalue = [0, 0, 23, 4, 0, 0]'),
#  Text(0.49195876288659796, 0.6904761904761905, 'x[4] <= 0.067\ngini = 0.204\nsamples = 26\nvalue = [0, 0, 23, 3, 0, 0]'),
#  Text(0.488659793814433, 0.6428571428571429, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.4952577319587629, 0.6428571428571429, 'x[1] <= 0.535\ngini = 0.147\nsamples = 25\nvalue = [0, 0, 23, 2, 0, 0]'),
#  Text(0.49195876288659796, 0.5952380952380952, 'x[2] <= 0.315\ngini = 0.32\nsamples = 10\nvalue = [0, 0, 8, 2, 0, 0]'),
#  Text(0.488659793814433, 0.5476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.4952577319587629, 0.5476190476190477, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 8, 0, 0, 0]'),
#  Text(0.49855670103092786, 0.5952380952380952, 'gini = 0.0\nsamples = 15\nvalue = [0, 0, 15, 0, 0, 0]'),
#  Text(0.49855670103092786, 0.6904761904761905, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.5084536082474227, 0.7380952380952381, 'x[9] <= 1.965\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(0.5051546391752577, 0.6904761904761905, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.5117525773195877, 0.6904761904761905, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.5183505154639175, 0.7857142857142857, 'x[3] <= 1.6\ngini = 0.07\nsamples = 56\nvalue = [0, 1, 54, 1, 0, 0]'),
#  Text(0.5150515463917525, 0.7380952380952381, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.5216494845360825, 0.7380952380952381, 'x[8] <= 3.09\ngini = 0.036\nsamples = 55\nvalue = [0, 0, 54, 1, 0, 0]'),
#  Text(0.5183505154639175, 0.6904761904761905, 'x[1] <= 0.56\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 4, 1, 0, 0]'),
#  Text(0.5150515463917525, 0.6428571428571429, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.5216494845360825, 0.6428571428571429, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.5249484536082474, 0.6904761904761905, 'gini = 0.0\nsamples = 50\nvalue = [0, 0, 50, 0, 0, 0]'),
#  Text(0.516701030927835, 0.8333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.7011082474226804, 0.9285714285714286, 'x[1] <= 0.335\ngini = 0.645\nsamples = 455\nvalue = [2, 16, 79, 232, 114, 12]'),
#  Text(0.6001030927835052, 0.8809523809523809, 'x[9] <= 0.735\ngini = 0.599\nsamples = 103\nvalue = [0, 1, 10, 38, 52, 2]'),
#  Text(0.5663917525773196, 0.8333333333333334, 'x[7] <= 0.995\ngini = 0.619\nsamples = 50\nvalue = [0, 1, 6, 25, 17, 1]'),
#  Text(0.5414432989690722, 0.7857142857142857, 'x[3] <= 1.95\ngini = 0.526\nsamples = 19\nvalue = [0, 0, 0, 7, 11, 1]'),
#  Text(0.5348453608247423, 0.7380952380952381, 'x[0] <= 8.4\ngini = 0.494\nsamples = 9\nvalue = [0, 0, 0, 6, 2, 1]'),
#  Text(0.5315463917525773, 0.6904761904761905, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(0.5381443298969072, 0.6904761904761905, 'x[0] <= 9.45\ngini = 0.625\nsamples = 4\nvalue = [0, 0, 0, 1, 2, 1]'),
#  Text(0.5348453608247423, 0.6428571428571429, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.5414432989690722, 0.6428571428571429, 'x[7] <= 0.995\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 0, 1]'),
#  Text(0.5381443298969072, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.5447422680412372, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.548041237113402, 0.7380952380952381, 'x[1] <= 0.205\ngini = 0.18\nsamples = 10\nvalue = [0, 0, 0, 1, 9, 0]'),
#  Text(0.5447422680412372, 0.6904761904761905, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.551340206185567, 0.6904761904761905, 'gini = 0.0\nsamples = 9\nvalue = [0, 0, 0, 0, 9, 0]'),
#  Text(0.591340206185567, 0.7857142857142857, 'x[0] <= 10.95\ngini = 0.587\nsamples = 31\nvalue = [0, 1, 6, 18, 6, 0]'),
#  Text(0.5785567010309278, 0.7380952380952381, 'x[8] <= 3.385\ngini = 0.51\nsamples = 27\nvalue = [0, 1, 4, 18, 4, 0]'),
#  Text(0.5628865979381443, 0.6904761904761905, 'x[4] <= 0.058\ngini = 0.349\nsamples = 19\nvalue = [0, 1, 0, 15, 3, 0]'),
#  Text(0.554639175257732, 0.6428571428571429, 'x[10] <= 11.35\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 0, 1, 0]'),
#  Text(0.551340206185567, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.5579381443298969, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.5711340206185567, 0.6428571428571429, 'x[3] <= 3.3\ngini = 0.208\nsamples = 17\nvalue = [0, 0, 0, 15, 2, 0]'),
#  Text(0.5645360824742268, 0.5952380952380952, 'x[1] <= 0.235\ngini = 0.124\nsamples = 15\nvalue = [0, 0, 0, 14, 1, 0]'),
#  Text(0.5612371134020618, 0.5476190476190477, 'x[9] <= 0.63\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 2, 1, 0]'),
#  Text(0.5579381443298969, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.5645360824742268, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.5678350515463918, 0.5476190476190477, 'gini = 0.0\nsamples = 12\nvalue = [0, 0, 0, 12, 0, 0]'),
#  Text(0.5777319587628866, 0.5952380952380952, 'x[0] <= 8.7\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0]'),
#  Text(0.5744329896907217, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.5810309278350515, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.5942268041237113, 0.6904761904761905, 'x[6] <= 40.5\ngini = 0.594\nsamples = 8\nvalue = [0, 0, 4, 3, 1, 0]'),
#  Text(0.5876288659793815, 0.6428571428571429, 'x[2] <= 0.35\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 3, 0, 1, 0]'),
#  Text(0.5843298969072165, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.5909278350515464, 0.5952380952380952, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.6008247422680413, 0.6428571428571429, 'x[9] <= 0.645\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 1, 3, 0, 0]'),
#  Text(0.5975257731958763, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.6041237113402061, 0.5952380952380952, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.6041237113402061, 0.7380952380952381, 'x[9] <= 0.64\ngini = 0.5\nsamples = 4\nvalue = [0, 0, 2, 0, 2, 0]'),
#  Text(0.6008247422680413, 0.6904761904761905, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.6074226804123711, 0.6904761904761905, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.6338144329896908, 0.8333333333333334, 'x[6] <= 53.0\ngini = 0.498\nsamples = 53\nvalue = [0, 0, 4, 13, 35, 1]'),
#  Text(0.6272164948453608, 0.7857142857142857, 'x[3] <= 2.95\ngini = 0.385\nsamples = 44\nvalue = [0, 0, 0, 10, 33, 1]'),
#  Text(0.6239175257731959, 0.7380952380952381, 'x[3] <= 2.025\ngini = 0.322\nsamples = 41\nvalue = [0, 0, 0, 7, 33, 1]'),
#  Text(0.617319587628866, 0.6904761904761905, 'x[2] <= 0.475\ngini = 0.465\nsamples = 19\nvalue = [0, 0, 0, 7, 12, 0]'),
#  Text(0.614020618556701, 0.6428571428571429, 'x[8] <= 3.425\ngini = 0.245\nsamples = 14\nvalue = [0, 0, 0, 2, 12, 0]'),
#  Text(0.6107216494845361, 0.5952380952380952, 'x[6] <= 39.5\ngini = 0.142\nsamples = 13\nvalue = [0, 0, 0, 1, 12, 0]'),
#  Text(0.6074226804123711, 0.5476190476190477, 'gini = 0.0\nsamples = 12\nvalue = [0, 0, 0, 0, 12, 0]'),
#  Text(0.614020618556701, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.617319587628866, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.6206185567010309, 0.6428571428571429, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(0.6305154639175258, 0.6904761904761905, 'x[9] <= 0.91\ngini = 0.087\nsamples = 22\nvalue = [0, 0, 0, 0, 21, 1]'),
#  Text(0.6272164948453608, 0.6428571428571429, 'gini = 0.0\nsamples = 18\nvalue = [0, 0, 0, 0, 18, 0]'),
#  Text(0.6338144329896908, 0.6428571428571429, 'x[9] <= 0.97\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 0, 0, 3, 1]'),
# ...
#  Text(0.7327835051546392, 0.4523809523809524, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 8, 0, 0]'),
#  Text(0.7360824742268042, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.742680412371134, 0.5952380952380952, 'x[2] <= 0.025\ngini = 0.625\nsamples = 4\nvalue = [0, 1, 2, 1, 0, 0]'),
#  Text(0.739381443298969, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.745979381443299, 0.5476190476190477, 'x[8] <= 3.34\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 1, 0, 0]'),
#  Text(0.742680412371134, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.7492783505154639, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.7410309278350515, 0.6428571428571429, 'gini = 0.0\nsamples = 12\nvalue = [0, 0, 0, 12, 0, 0]'),
#  Text(0.7558762886597938, 0.6904761904761905, 'x[9] <= 0.54\ngini = 0.611\nsamples = 6\nvalue = [0, 0, 3, 1, 2, 0]'),
#  Text(0.7525773195876289, 0.6428571428571429, 'x[9] <= 0.47\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 3, 1, 0, 0]'),
#  Text(0.7492783505154639, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.7558762886597938, 0.5952380952380952, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.7591752577319587, 0.6428571428571429, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.9009278350515464, 0.8333333333333334, 'x[6] <= 109.5\ngini = 0.567\nsamples = 247\nvalue = [0, 3, 30, 150, 54, 10]'),
#  Text(0.8976288659793814, 0.7857142857142857, 'x[3] <= 3.45\ngini = 0.556\nsamples = 243\nvalue = [0, 3, 26, 150, 54, 10]'),
#  Text(0.8402061855670103, 0.7380952380952381, 'x[9] <= 0.685\ngini = 0.514\nsamples = 210\nvalue = [0, 2, 21, 139, 40, 8]'),
#  Text(0.7863917525773196, 0.6904761904761905, 'x[5] <= 6.5\ngini = 0.361\nsamples = 90\nvalue = [0, 2, 9, 71, 7, 1]'),
#  Text(0.774020618556701, 0.6428571428571429, 'x[10] <= 11.55\ngini = 0.671\nsamples = 17\nvalue = [0, 2, 1, 8, 5, 1]'),
#  Text(0.7657731958762887, 0.5952380952380952, 'x[8] <= 3.47\ngini = 0.611\nsamples = 12\nvalue = [0, 2, 1, 7, 1, 1]'),
#  Text(0.7591752577319587, 0.5476190476190477, 'x[1] <= 0.355\ngini = 0.37\nsamples = 9\nvalue = [0, 0, 0, 7, 1, 1]'),
#  Text(0.7558762886597938, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.7624742268041237, 0.5, 'x[10] <= 10.7\ngini = 0.219\nsamples = 8\nvalue = [0, 0, 0, 7, 1, 0]'),
#  Text(0.7591752577319587, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.7657731958762887, 0.4523809523809524, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 7, 0, 0]'),
#  Text(0.7723711340206185, 0.5476190476190477, 'x[9] <= 0.625\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1, 0, 0, 0]'),
#  Text(0.7690721649484537, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0, 0]'),
#  Text(0.7756701030927835, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.7822680412371134, 0.5952380952380952, 'x[6] <= 9.5\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 0, 1, 4, 0]'),
#  Text(0.7789690721649485, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.7855670103092783, 0.5476190476190477, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 0, 4, 0]'),
#  Text(0.7987628865979381, 0.6428571428571429, 'x[10] <= 12.95\ngini = 0.242\nsamples = 73\nvalue = [0, 0, 8, 63, 2, 0]'),
#  Text(0.7954639175257732, 0.5952380952380952, 'x[4] <= 0.142\ngini = 0.205\nsamples = 71\nvalue = [0, 0, 6, 63, 2, 0]'),
#  Text(0.7921649484536083, 0.5476190476190477, 'x[6] <= 99.0\ngini = 0.184\nsamples = 70\nvalue = [0, 0, 5, 63, 2, 0]'),
#  Text(0.7822680412371134, 0.5, 'x[9] <= 0.665\ngini = 0.163\nsamples = 68\nvalue = [0, 0, 5, 62, 1, 0]'),
#  Text(0.7723711340206185, 0.4523809523809524, 'x[0] <= 6.35\ngini = 0.104\nsamples = 55\nvalue = [0, 0, 2, 52, 1, 0]'),
#  Text(0.7624742268041237, 0.40476190476190477, 'x[0] <= 6.15\ngini = 0.32\nsamples = 10\nvalue = [0, 0, 2, 8, 0, 0]'),
#  Text(0.7591752577319587, 0.35714285714285715, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 7, 0, 0]'),
#  Text(0.7657731958762887, 0.35714285714285715, 'x[2] <= 0.045\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 1, 0, 0]'),
#  Text(0.7624742268041237, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.7690721649484537, 0.30952380952380953, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.7822680412371134, 0.40476190476190477, 'x[7] <= 0.994\ngini = 0.043\nsamples = 45\nvalue = [0, 0, 0, 44, 1, 0]'),
#  Text(0.7789690721649485, 0.35714285714285715, 'x[10] <= 11.85\ngini = 0.245\nsamples = 7\nvalue = [0, 0, 0, 6, 1, 0]'),
#  Text(0.7756701030927835, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.7822680412371134, 0.30952380952380953, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0]'),
#  Text(0.7855670103092783, 0.35714285714285715, 'gini = 0.0\nsamples = 38\nvalue = [0, 0, 0, 38, 0, 0]'),
#  Text(0.7921649484536083, 0.4523809523809524, 'x[2] <= 0.28\ngini = 0.355\nsamples = 13\nvalue = [0, 0, 3, 10, 0, 0]'),
#  Text(0.7888659793814433, 0.40476190476190477, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 8, 0, 0]'),
#  Text(0.7954639175257732, 0.40476190476190477, 'x[7] <= 0.998\ngini = 0.48\nsamples = 5\nvalue = [0, 0, 3, 2, 0, 0]'),
#  Text(0.7921649484536083, 0.35714285714285715, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.7987628865979381, 0.35714285714285715, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.8020618556701031, 0.5, 'x[0] <= 4.95\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0]'),
#  Text(0.7987628865979381, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.805360824742268, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.7987628865979381, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.8020618556701031, 0.5952380952380952, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.894020618556701, 0.6904761904761905, 'x[5] <= 21.5\ngini = 0.59\nsamples = 120\nvalue = [0, 0, 12, 68, 33, 7]'),
#  Text(0.8540206185567011, 0.6428571428571429, 'x[6] <= 24.5\ngini = 0.663\nsamples = 78\nvalue = [0, 0, 10, 35, 26, 7]'),
#  Text(0.8235051546391753, 0.5952380952380952, 'x[9] <= 0.725\ngini = 0.507\nsamples = 37\nvalue = [0, 0, 3, 25, 5, 4]'),
#  Text(0.811958762886598, 0.5476190476190477, 'x[10] <= 11.15\ngini = 0.684\nsamples = 14\nvalue = [0, 0, 1, 6, 3, 4]'),
#  Text(0.808659793814433, 0.5, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(0.8152577319587628, 0.5, 'x[3] <= 1.85\ngini = 0.667\nsamples = 9\nvalue = [0, 0, 1, 1, 3, 4]'),
#  Text(0.811958762886598, 0.4523809523809524, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 0, 3]'),
#  Text(0.8185567010309278, 0.4523809523809524, 'x[6] <= 15.0\ngini = 0.667\nsamples = 6\nvalue = [0, 0, 1, 1, 3, 1]'),
#  Text(0.8152577319587628, 0.40476190476190477, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]'),
#  Text(0.8218556701030928, 0.40476190476190477, 'x[1] <= 0.455\ngini = 0.667\nsamples = 3\nvalue = [0, 0, 1, 1, 0, 1]'),
#  Text(0.8185567010309278, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.8251546391752578, 0.35714285714285715, 'x[1] <= 0.51\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 0, 0, 1]'),
#  Text(0.8218556701030928, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.8284536082474226, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.8350515463917526, 0.5476190476190477, 'x[10] <= 10.65\ngini = 0.302\nsamples = 23\nvalue = [0, 0, 2, 19, 2, 0]'),
#  Text(0.8284536082474226, 0.5, 'x[9] <= 0.755\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 1, 0, 0]'),
#  Text(0.8251546391752578, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.8317525773195876, 0.4523809523809524, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.8416494845360825, 0.5, 'x[1] <= 0.45\ngini = 0.18\nsamples = 20\nvalue = [0, 0, 0, 18, 2, 0]'),
#  Text(0.8383505154639175, 0.4523809523809524, 'x[3] <= 2.05\ngini = 0.408\nsamples = 7\nvalue = [0, 0, 0, 5, 2, 0]'),
#  Text(0.8350515463917526, 0.40476190476190477, 'x[4] <= 0.057\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 1, 2, 0]'),
#  Text(0.8317525773195876, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.8383505154639175, 0.35714285714285715, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.8416494845360825, 0.40476190476190477, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.8449484536082474, 0.4523809523809524, 'gini = 0.0\nsamples = 13\nvalue = [0, 0, 0, 13, 0, 0]'),
#  Text(0.8845360824742268, 0.5952380952380952, 'x[10] <= 11.25\ngini = 0.644\nsamples = 41\nvalue = [0, 0, 7, 10, 21, 3]'),
#  Text(0.8630927835051546, 0.5476190476190477, 'x[9] <= 0.745\ngini = 0.656\nsamples = 16\nvalue = [0, 0, 6, 6, 4, 0]'),
#  Text(0.8548453608247423, 0.5, 'x[6] <= 34.0\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 4, 0, 1, 0]'),
#  Text(0.8515463917525773, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.8581443298969073, 0.4523809523809524, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.871340206185567, 0.5, 'x[4] <= 0.067\ngini = 0.595\nsamples = 11\nvalue = [0, 0, 2, 6, 3, 0]'),
#  Text(0.8647422680412371, 0.4523809523809524, 'x[3] <= 2.05\ngini = 0.5\nsamples = 4\nvalue = [0, 0, 2, 0, 2, 0]'),
#  Text(0.8614432989690721, 0.40476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.8680412371134021, 0.40476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.8779381443298969, 0.4523809523809524, 'x[4] <= 0.089\ngini = 0.245\nsamples = 7\nvalue = [0, 0, 0, 6, 1, 0]'),
#  Text(0.8746391752577319, 0.40476190476190477, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0]'),
#  Text(0.8812371134020619, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.9059793814432989, 0.5476190476190477, 'x[4] <= 0.088\ngini = 0.496\nsamples = 25\nvalue = [0, 0, 1, 4, 17, 3]'),
#  Text(0.8977319587628866, 0.5, 'x[1] <= 0.833\ngini = 0.395\nsamples = 21\nvalue = [0, 0, 1, 1, 16, 3]'),
#  Text(0.8911340206185567, 0.4523809523809524, 'x[8] <= 3.715\ngini = 0.277\nsamples = 19\nvalue = [0, 0, 0, 1, 16, 2]'),
#  Text(0.8878350515463918, 0.40476190476190477, 'x[8] <= 3.235\ngini = 0.204\nsamples = 18\nvalue = [0, 0, 0, 1, 16, 1]'),
#  Text(0.8845360824742268, 0.35714285714285715, 'x[6] <= 28.5\ngini = 0.56\nsamples = 5\nvalue = [0, 0, 0, 1, 3, 1]'),
#  Text(0.8812371134020619, 0.30952380952380953, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]'),
#  Text(0.8878350515463918, 0.30952380952380953, 'x[1] <= 0.44\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 0, 1]'),
#  Text(0.8845360824742268, 0.2619047619047619, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.8911340206185567, 0.2619047619047619, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.8911340206185567, 0.35714285714285715, 'gini = 0.0\nsamples = 13\nvalue = [0, 0, 0, 0, 13, 0]'),
#  Text(0.8944329896907216, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.9043298969072165, 0.4523809523809524, 'x[6] <= 83.0\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 0, 0, 1]'),
#  Text(0.9010309278350516, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.9076288659793814, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.9142268041237114, 0.5, 'x[0] <= 10.2\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 0, 3, 1, 0]'),
#  Text(0.9109278350515464, 0.4523809523809524, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.9175257731958762, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.934020618556701, 0.6428571428571429, 'x[2] <= 0.45\ngini = 0.353\nsamples = 42\nvalue = [0, 0, 2, 33, 7, 0]'),
#  Text(0.9274226804123711, 0.5952380952380952, 'x[1] <= 0.515\ngini = 0.208\nsamples = 34\nvalue = [0, 0, 0, 30, 4, 0]'),
#  Text(0.9241237113402062, 0.5476190476190477, 'gini = 0.0\nsamples = 20\nvalue = [0, 0, 0, 20, 0, 0]'),
#  Text(0.9307216494845361, 0.5476190476190477, 'x[1] <= 0.595\ngini = 0.408\nsamples = 14\nvalue = [0, 0, 0, 10, 4, 0]'),
#  Text(0.9274226804123711, 0.5, 'x[5] <= 38.0\ngini = 0.5\nsamples = 8\nvalue = [0, 0, 0, 4, 4, 0]'),
#  Text(0.9241237113402062, 0.4523809523809524, 'x[2] <= 0.4\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 0, 1, 4, 0]'),
#  Text(0.9208247422680412, 0.40476190476190477, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 0, 4, 0]'),
#  Text(0.9274226804123711, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.9307216494845361, 0.4523809523809524, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.934020618556701, 0.5, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0]'),
#  Text(0.9406185567010309, 0.5952380952380952, 'x[3] <= 2.3\ngini = 0.656\nsamples = 8\nvalue = [0, 0, 2, 3, 3, 0]'),
#  Text(0.937319587628866, 0.5476190476190477, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]'),
#  Text(0.9439175257731959, 0.5476190476190477, 'x[10] <= 11.05\ngini = 0.48\nsamples = 5\nvalue = [0, 0, 2, 3, 0, 0]'),
#  Text(0.9406185567010309, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.9472164948453609, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.9550515463917526, 0.7380952380952381, 'x[4] <= 0.075\ngini = 0.681\nsamples = 33\nvalue = [0, 1, 5, 11, 14, 2]'),
#  Text(0.9439175257731959, 0.6904761904761905, 'x[0] <= 6.5\ngini = 0.219\nsamples = 8\nvalue = [0, 0, 0, 1, 7, 0]'),
#  Text(0.9406185567010309, 0.6428571428571429, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.9472164948453609, 0.6428571428571429, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 0, 7, 0]'),
#  Text(0.9661855670103093, 0.6904761904761905, 'x[4] <= 0.089\ngini = 0.714\nsamples = 25\nvalue = [0, 1, 5, 10, 7, 2]'),
#  Text(0.9538144329896907, 0.6428571428571429, 'x[10] <= 12.75\ngini = 0.346\nsamples = 9\nvalue = [0, 0, 0, 7, 0, 2]'),
#  Text(0.9505154639175257, 0.5952380952380952, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0]'),
#  Text(0.9571134020618557, 0.5952380952380952, 'x[0] <= 11.35\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 1, 0, 2]'),
#  Text(0.9538144329896907, 0.5476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 2]'),
#  Text(0.9604123711340207, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.9785567010309278, 0.6428571428571429, 'x[7] <= 0.997\ngini = 0.672\nsamples = 16\nvalue = [0, 1, 5, 3, 7, 0]'),
#  Text(0.9703092783505155, 0.5952380952380952, 'x[8] <= 3.435\ngini = 0.32\nsamples = 5\nvalue = [0, 1, 0, 0, 4, 0]'),
#  Text(0.9670103092783505, 0.5476190476190477, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 0, 4, 0]'),
#  Text(0.9736082474226804, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.9868041237113402, 0.5952380952380952, 'x[2] <= 0.655\ngini = 0.645\nsamples = 11\nvalue = [0, 0, 5, 3, 3, 0]'),
#  Text(0.9802061855670103, 0.5476190476190477, 'x[0] <= 14.75\ngini = 0.49\nsamples = 7\nvalue = [0, 0, 4, 3, 0, 0]'),
#  Text(0.9769072164948454, 0.5, 'x[8] <= 3.265\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 1, 3, 0, 0]'),
#  Text(0.9736082474226804, 0.4523809523809524, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.9802061855670103, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.9835051546391752, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.9934020618556701, 0.5476190476190477, 'x[3] <= 4.775\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 1, 0, 3, 0]'),
#  Text(0.9901030927835052, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]'),
#  Text(0.996701030927835, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.9042268041237114, 0.7857142857142857, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]')]

# %%
sampledata=dataframe.head(20)
sampledata
# Out:
#     fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             7.4             0.700         0.00             1.9      0.076
# 1             7.8             0.880         0.00             2.6      0.098
# 2             7.8             0.760         0.04             2.3      0.092
# 3            11.2             0.280         0.56             1.9      0.075
# 4             7.4             0.700         0.00             1.9      0.076
# 5             7.4             0.660         0.00             1.8      0.075
# 6             7.9             0.600         0.06             1.6      0.069
# 7             7.3             0.650         0.00             1.2      0.065
# 8             7.8             0.580         0.02             2.0      0.073
# 9             7.5             0.500         0.36             6.1      0.071
# 10            6.7             0.580         0.08             1.8      0.097
# 11            7.5             0.500         0.36             6.1      0.071
# 12            5.6             0.615         0.00             1.6      0.089
# 13            7.8             0.610         0.29             1.6      0.114
# 14            8.9             0.620         0.18             3.8      0.176
# 15            8.9             0.620         0.19             3.9      0.170
# 16            8.5             0.280         0.56             1.8      0.092
# 17            8.1             0.560         0.28             1.7      0.368
# 18            7.4             0.590         0.08             4.4      0.086
# 19            7.9             0.320         0.51             1.8      0.341
#
#     free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                  11.0                  34.0   0.9978  3.51       0.56
# 1                  25.0                  67.0   0.9968  3.20       0.68
# 2                  15.0                  54.0   0.9970  3.26       0.65
# 3                  17.0                  60.0   0.9980  3.16       0.58
# 4                  11.0                  34.0   0.9978  3.51       0.56
# 5                  13.0                  40.0   0.9978  3.51       0.56
# 6                  15.0                  59.0   0.9964  3.30       0.46
# 7                  15.0                  21.0   0.9946  3.39       0.47
# 8                   9.0                  18.0   0.9968  3.36       0.57
# 9                  17.0                 102.0   0.9978  3.35       0.80
# 10                 15.0                  65.0   0.9959  3.28       0.54
# 11                 17.0                 102.0   0.9978  3.35       0.80
# 12                 16.0                  59.0   0.9943  3.58       0.52
# 13                  9.0                  29.0   0.9974  3.26       1.56
# 14                 52.0                 145.0   0.9986  3.16       0.88
# 15                 51.0                 148.0   0.9986  3.17       0.93
# 16                 35.0                 103.0   0.9969  3.30       0.75
# 17                 16.0                  56.0   0.9968  3.11       1.28
# 18                  6.0                  29.0   0.9974  3.38       0.50
# 19                 17.0                  56.0   0.9969  3.04       1.08
#
#     alcohol  quality
# 0       9.4        5
# 1       9.8        5
# 2       9.8        5
# 3       9.8        6
# 4       9.4        5
# 5       9.4        5
# 6       9.4        5
# 7      10.0        7
# 8       9.5        7
# 9      10.5        5
# 10      9.2        5
# 11     10.5        5
# 12      9.9        5
# 13      9.1        5
# 14      9.2        5
# 15      9.2        5
# 16     10.5        7
# 17      9.3        5
# 18      9.0        4
# 19      9.2        6

# %%
x_sample=sampledata.drop(columns='quality',axis=1)
y_sample=sampledata['quality']

# %%
samplemodel=DecisionTreeClassifier()
samplemodel.fit(x_sample,y_sample)
# Out:
# DecisionTreeClassifier()

# %%
sampledata.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
from sklearn import tree
plt.figure(figsize=(20,20))
tree.plot_tree(samplemodel,filled=True)
# Out:
# [Text(0.4444444444444444, 0.875, 'x[1] <= 0.41\ngini = 0.475\nsamples = 20\nvalue = [1, 14, 2, 3]'),
#  Text(0.2222222222222222, 0.625, 'x[6] <= 81.5\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 1]'),
#  Text(0.1111111111111111, 0.375, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0]'),
#  Text(0.3333333333333333, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]'),
#  Text(0.6666666666666666, 0.625, 'x[6] <= 25.0\ngini = 0.304\nsamples = 17\nvalue = [1, 14, 0, 2]'),
#  Text(0.5555555555555556, 0.375, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]'),
#  Text(0.7777777777777778, 0.375, 'x[5] <= 7.5\ngini = 0.124\nsamples = 15\nvalue = [1, 14, 0, 0]'),
#  Text(0.6666666666666666, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]'),
#  Text(0.8888888888888888, 0.125, 'gini = 0.0\nsamples = 14\nvalue = [0, 14, 0, 0]')]

# %%
MSE = np.square(np.subtract(y_test,y_pred)).mean()

# %%
MSE
# Out:
# 0.5875

# %%
import math

# %%
rmse = math.sqrt(MSE)

# %%
rmse
# Out:
# 0.7664854858377946
